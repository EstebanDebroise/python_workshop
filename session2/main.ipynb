# %%
names = ["a", "b"]
for name in names:
    print(name)

# %%
x = [-2, 0, 1, 3, -5]
count = sum(1 for i in x if i >0)
print(count)
# Out:
# 3

# %%
numbers = [1, 2, 3, 4, 5]
total = sum(numbers)
print(total)
# Out:
# 15

# %%
numbers = [1, 2, 3, 4, 5]
result = [n for n in numbers if n % 2 == 0]
print(result)
# Out:
# [2, 4]

# %%
words = ["bonjour", "baguette", "python"]
sentence = ", ".join(words)
print(sentence)
# Out:
# bonjour, baguette, python

# %%
keys = ["a", "b", "c", "d", "a", "b", "d"]
d = {k: keys.count(k) for k in keys}
print(d)
# Out:
# {'a': 2, 'b': 2, 'c': 1, 'd': 2}

# %%
listwords = ["bonjour", "baguette", "python", "abricot", "avion"]
result = [w for w in listwords if w.startswith("a")]
print(result)
# Out:
# ['abricot', 'avion']
